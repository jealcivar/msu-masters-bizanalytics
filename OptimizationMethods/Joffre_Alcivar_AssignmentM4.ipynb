# %%
# %%capture
# !pip install -q pyomo
# !apt-get install -y -qq glpk-utils

# %%
from pyomo.environ import *

# %% [markdown]
# # Question 1

# %%
# Create a model
model1 = ConcreteModel()

source1 = ['plant1', 'plant2', 'plant3']

dest1 = ['dc1', 'dc2', 'dc3', 'dc4']

# Declare variables
model1.x = Var(source1, dest1, domain=NonNegativeReals)

# Objective function
model1.shippingcost = Objective(expr = (800*0.5 + 100)*model1.x[source1[0], dest1[0]] + 
                                (1300*0.5 + 100)*model1.x[source1[0], dest1[1]] + 
                                (400*0.5 + 100)*model1.x[source1[0], dest1[2]] + 
                                (700*0.5 + 100)*model1.x[source1[0], dest1[3]] + 
                                (1100*0.5 + 100)*model1.x[source1[1], dest1[0]] + 
                                (1400*0.5 + 100)*model1.x[source1[1], dest1[1]] + 
                                (600*0.5 + 100)*model1.x[source1[1], dest1[2]] + 
                                (1000*0.5 + 100)*model1.x[source1[1], dest1[3]] + 
                                (600*0.5 + 100)*model1.x[source1[2], dest1[0]] + 
                                (1200*0.5 + 100)*model1.x[source1[2], dest1[1]] + 
                                (800*0.5 + 100)*model1.x[source1[2], dest1[2]] + 
                                (900*0.5 + 100)*model1.x[source1[2], dest1[3]], sense = minimize)

# Constraints
model1.plant1 = Constraint(expr = model1.x[source1[0], dest1[0]] + 
                           model1.x[source1[0], dest1[1]] + 
                           model1.x[source1[0], dest1[2]] + 
                           model1.x[source1[0], dest1[3]] == 12)
model1.plant2 = Constraint(expr = model1.x[source1[1], dest1[0]] + 
                           model1.x[source1[1], dest1[1]] + 
                           model1.x[source1[1], dest1[2]] + 
                           model1.x[source1[1], dest1[3]] == 17)
model1.plant3 = Constraint(expr = model1.x[source1[2], dest1[0]] + 
                           model1.x[source1[2], dest1[1]] + 
                           model1.x[source1[2], dest1[2]] + 
                           model1.x[source1[2], dest1[3]] == 11)


model1.dc1 = Constraint(expr = model1.x[source1[0], dest1[0]] + model1.x[source1[1], dest1[0]] + model1.x[source1[2], dest1[0]] == 10)
model1.dc2 = Constraint(expr = model1.x[source1[0], dest1[1]] + model1.x[source1[1], dest1[1]] + model1.x[source1[2], dest1[1]] == 10)
model1.dc3 = Constraint(expr = model1.x[source1[0], dest1[2]] + model1.x[source1[1], dest1[2]] + model1.x[source1[2], dest1[2]] == 10)
model1.dc4 = Constraint(expr = model1.x[source1[0], dest1[3]] + model1.x[source1[1], dest1[3]] + model1.x[source1[2], dest1[3]] == 10)

# Solve
results = SolverFactory('glpk').solve(model1)
results.write()
model1.pprint()

print ('\nShipments from Plant to Distribution Center: \n')
for s in source1:
  for d in dest1:
    print (s, 'to', d, ':', model1.x[s, d](), 'shipments')

print('\n Shipping Cost: $', model1.shippingcost())
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 20200.0
#   Upper bound: 20200.0
#   Number of objectives: 1
#   Number of constraints: 8
#   Number of variables: 13
#   Number of nonzeros: 25
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.009799957275390625
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# 3 Set Declarations
#     x_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : x_index_0*x_index_1 :   12 : {('plant1', 'dc1'), ('plant1', 'dc2'), ('plant1', 'dc3'), ('plant1', 'dc4'), ('plant2', 'dc1'), ('plant2', 'dc2'), ('plant2', 'dc3'), ('plant2', 'dc4'), ('plant3', 'dc1'), ('plant3', 'dc2'), ('plant3', 'dc3'), ('plant3', 'dc4')}
#     x_index_0 : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'plant1', 'plant2', 'plant3'}
#     x_index_1 : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {'dc1', 'dc2', 'dc3', 'dc4'}
#
# 1 Var Declarations
#     x : Size=12, Index=x_index
#         Key               : Lower : Value : Upper : Fixed : Stale : Domain
#         ('plant1', 'dc1') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         ('plant1', 'dc2') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         ('plant1', 'dc3') :     0 :   2.0 :  None : False : False : NonNegativeReals
#         ('plant1', 'dc4') :     0 :  10.0 :  None : False : False : NonNegativeReals
#         ('plant2', 'dc1') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         ('plant2', 'dc2') :     0 :   9.0 :  None : False : False : NonNegativeReals
#         ('plant2', 'dc3') :     0 :   8.0 :  None : False : False : NonNegativeReals
#         ('plant2', 'dc4') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         ('plant3', 'dc1') :     0 :  10.0 :  None : False : False : NonNegativeReals
#         ('plant3', 'dc2') :     0 :   1.0 :  None : False : False : NonNegativeReals
#         ('plant3', 'dc3') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         ('plant3', 'dc4') :     0 :   0.0 :  None : False : False : NonNegativeReals
#
# 1 Objective Declarations
#     shippingcost : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 500.0*x[plant1,dc1] + 750.0*x[plant1,dc2] + 300.0*x[plant1,dc3] + 450.0*x[plant1,dc4] + 650.0*x[plant2,dc1] + 800.0*x[plant2,dc2] + 400.0*x[plant2,dc3] + 600.0*x[plant2,dc4] + 400.0*x[plant3,dc1] + 700.0*x[plant3,dc2] + 500.0*x[plant3,dc3] + 550.0*x[plant3,dc4]
#
# 7 Constraint Declarations
#     dc1 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                          : Upper : Active
#         None :  10.0 : x[plant1,dc1] + x[plant2,dc1] + x[plant3,dc1] :  10.0 :   True
#     dc2 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                          : Upper : Active
#         None :  10.0 : x[plant1,dc2] + x[plant2,dc2] + x[plant3,dc2] :  10.0 :   True
#     dc3 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                          : Upper : Active
#         None :  10.0 : x[plant1,dc3] + x[plant2,dc3] + x[plant3,dc3] :  10.0 :   True
#     dc4 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                          : Upper : Active
#         None :  10.0 : x[plant1,dc4] + x[plant2,dc4] + x[plant3,dc4] :  10.0 :   True
#     plant1 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                          : Upper : Active
#         None :  12.0 : x[plant1,dc1] + x[plant1,dc2] + x[plant1,dc3] + x[plant1,dc4] :  12.0 :   True
#     plant2 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                          : Upper : Active
#         None :  17.0 : x[plant2,dc1] + x[plant2,dc2] + x[plant2,dc3] + x[plant2,dc4] :  17.0 :   True
#     plant3 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                          : Upper : Active
#         None :  11.0 : x[plant3,dc1] + x[plant3,dc2] + x[plant3,dc3] + x[plant3,dc4] :  11.0 :   True
#
# 12 Declarations: x_index_0 x_index_1 x_index x shippingcost plant1 plant2 plant3 dc1 dc2 dc3 dc4
#
# Shipments from Plant to Distribution Center:
#
# plant1 to dc1 : 0.0 shipments
# plant1 to dc2 : 0.0 shipments
# plant1 to dc3 : 2.0 shipments
# plant1 to dc4 : 10.0 shipments
# plant2 to dc1 : 0.0 shipments
# plant2 to dc2 : 9.0 shipments
# plant2 to dc3 : 8.0 shipments
# plant2 to dc4 : 0.0 shipments
# plant3 to dc1 : 10.0 shipments
# plant3 to dc2 : 1.0 shipments
# plant3 to dc3 : 0.0 shipments
# plant3 to dc4 : 0.0 shipments
#
#  Shipping Cost: $ 20200.0

# %% [markdown]
# # Question 2

# %%
# Create a model
model2 = ConcreteModel()

source2 = ['plantA', 'plantB']

dest2 = ['distc1', 'distc2', 'distc3']

# Declare variables
model2.x = Var(source2, dest2, domain=NonNegativeReals)

# Objective function
model2.shippingcost = Objective(expr = 800*model2.x[source2[0], dest2[0]] + 700*model2.x[source2[0], dest2[1]] + 400*model2.x[source2[0], dest2[2]] + 
                                600*model2.x[source2[1], dest2[0]] + 800*model2.x[source2[1], dest2[1]] + 500*model2.x[source2[1], dest2[2]], 
                                sense = minimize)

# Constraints
model2.plantA = Constraint(expr = model2.x[source2[0], dest2[0]] + model2.x[source2[0], dest2[1]] + model2.x[source2[0], dest2[2]] <= 50)
model2.plantB = Constraint(expr = model2.x[source2[1], dest2[0]] + model2.x[source2[1], dest2[1]] + model2.x[source2[1], dest2[2]] <= 50)

model2.distc1 = Constraint(expr = model2.x[source2[0], dest2[0]] + model2.x[source2[1], dest2[0]] == 20)
model2.distc2 = Constraint(expr = model2.x[source2[0], dest2[1]] + model2.x[source2[1], dest2[1]] == 20)
model2.distc3 = Constraint(expr = model2.x[source2[0], dest2[2]] + model2.x[source2[1], dest2[2]] == 20)

# Solve
results = SolverFactory('glpk').solve(model2)
results.write()
model2.pprint()

print ('\nCT Machines from Plant to Distribution Center: \n')
for s in source2:
  for d in dest2:
    print (s, 'to', d, ':', model2.x[s, d](), 'CT Machines')

print('\n Shipping Cost: $', model2.shippingcost())
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 34000.0
#   Upper bound: 34000.0
#   Number of objectives: 1
#   Number of constraints: 6
#   Number of variables: 7
#   Number of nonzeros: 13
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.01594853401184082
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# 3 Set Declarations
#     x_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : x_index_0*x_index_1 :    6 : {('plantA', 'distc1'), ('plantA', 'distc2'), ('plantA', 'distc3'), ('plantB', 'distc1'), ('plantB', 'distc2'), ('plantB', 'distc3')}
#     x_index_0 : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    2 : {'plantA', 'plantB'}
#     x_index_1 : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'distc1', 'distc2', 'distc3'}
#
# 1 Var Declarations
#     x : Size=6, Index=x_index
#         Key                  : Lower : Value : Upper : Fixed : Stale : Domain
#         ('plantA', 'distc1') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         ('plantA', 'distc2') :     0 :  20.0 :  None : False : False : NonNegativeReals
#         ('plantA', 'distc3') :     0 :  20.0 :  None : False : False : NonNegativeReals
#         ('plantB', 'distc1') :     0 :  20.0 :  None : False : False : NonNegativeReals
#         ('plantB', 'distc2') :     0 :   0.0 :  None : False : False : NonNegativeReals
#         ('plantB', 'distc3') :     0 :   0.0 :  None : False : False : NonNegativeReals
#
# 1 Objective Declarations
#     shippingcost : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 800*x[plantA,distc1] + 700*x[plantA,distc2] + 400*x[plantA,distc3] + 600*x[plantB,distc1] + 800*x[plantB,distc2] + 500*x[plantB,distc3]
#
# 5 Constraint Declarations
#     distc1 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                : Upper : Active
#         None :  20.0 : x[plantA,distc1] + x[plantB,distc1] :  20.0 :   True
#     distc2 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                : Upper : Active
#         None :  20.0 : x[plantA,distc2] + x[plantB,distc2] :  20.0 :   True
#     distc3 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                : Upper : Active
#         None :  20.0 : x[plantA,distc3] + x[plantB,distc3] :  20.0 :   True
#     plantA : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                   : Upper : Active
#         None :  -Inf : x[plantA,distc1] + x[plantA,distc2] + x[plantA,distc3] :  50.0 :   True
#     plantB : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                   : Upper : Active
#         None :  -Inf : x[plantB,distc1] + x[plantB,distc2] + x[plantB,distc3] :  50.0 :   True
#
# 10 Declarations: x_index_0 x_index_1 x_index x shippingcost plantA plantB distc1 distc2 distc3
#
# CT Machines from Plant to Distribution Center:
#
# plantA to distc1 : 0.0 CT Machines
# plantA to distc2 : 20.0 CT Machines
# plantA to distc3 : 20.0 CT Machines
# plantB to distc1 : 20.0 CT Machines
# plantB to distc2 : 0.0 CT Machines
# plantB to distc3 : 0.0 CT Machines
#
#  Shipping Cost: $ 34000.0
